# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiobarrostm/machine-learning/blob/master/An%C3%A1lise_de_dados_do_COVID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importando as bibliotecas**

# %%
  import pandas as pd
  import matplotlib.pyplot as plt

# %% [markdown]
# Para a análise dos dados do COVID utilizei um datasset disponível no repositório
# https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat  ...  8/20/20  8/21/20  8/22/20
# 0            NaN    Afghanistan  33.93911  ...    37856    37894    37953
# 1            NaN        Albania  41.15330  ...     7967     8119     8275
# 2            NaN        Algeria  28.03390  ...    40258    40667    41068
# 3            NaN        Andorra  42.50630  ...     1024     1045     1045
# 4            NaN         Angola -11.20270  ...     2044     2068     2134
#
# [5 rows x 218 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Columns: 218 entries, Province/State to 8/22/20
# dtypes: float64(2), int64(214), object(2)
# memory usage: 453.2+ KB

# %% [markdown]
# Elimando colunas de latitude e longitude

# %%
df.drop(['Lat' , 'Long'] , axis=1, inplace=True)

# %% [markdown]
# Agrupando dados por país

# %%
df_country = df.groupby('Country/Region').sum()

# %%
df_country.head(30)
# Out:
#                         1/22/20  1/23/20  1/24/20  ...  8/20/20  8/21/20  8/22/20
# Country/Region                                     ...
# Afghanistan                   0        0        0  ...    37856    37894    37953
# Albania                       0        0        0  ...     7967     8119     8275
# Algeria                       0        0        0  ...    40258    40667    41068
# Andorra                       0        0        0  ...     1024     1045     1045
# Angola                        0        0        0  ...     2044     2068     2134
# Antigua and Barbuda           0        0        0  ...       94       94       94
# Argentina                     0        0        0  ...   320884   329043   336802
# Armenia                       0        0        0  ...    42319    42477    42616
# Australia                     0        0        0  ...    24407    24602    24811
# Austria                       0        0        0  ...    24431    24762    25062
# ...

# %%
#capturando linha de dados do Brasil
brazil = df_country.loc['Brazil']

# %%
#descartando dados onde o número de casos confirmados foi 0
brazil = brazil[brazil > 0 ]

# %% [markdown]
# **Visualizando dados**

# %%
tam = len(brazil)
plt.figure(figsize=(14,8))
plt.xticks(rotation=50)
plt.title('Casos Confirmados de COVID no Brasil')
plt.xlabel('Data')
plt.ylabel('Casos confirmados')
plt.bar(brazil.index[tam-30:tam], brazil.values[tam-30:tam])
# Out:
# <BarContainer object of 30 artists>
